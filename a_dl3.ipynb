# %%
#installing scikit learn
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.3-cp39-cp39-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 4.8 MB/s eta 0:00:00
# Collecting joblib>=1.0.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      -------------------------------------- 298.0/298.0 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in c:\users\nitro\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\nitro\anaconda3\envs\tf\lib\site-packages (from scikit-learn) (1.21.5)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.1.3 threadpoolctl-3.1.0

# %%
# importing libraries

import numpy as np
import pandas as pd
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Conv2D,Dense,MaxPooling2D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# %%
# loading and preparing the data 

(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
X_train[0].min(), X_train[0].max()
# Out:
# (0, 255)

# %%
X_train = (X_train - 0.0) / (255.0 - 0.0)
X_test = (X_test - 0.0) / (255.0 - 0.0)
X_train[0].min(), X_train[0].max()
# Out:
# (0.0, 1.0)

# %%
def plot_digit(image, digit, plt, i):
 plt.subplot(4, 5, i + 1)
 plt.imshow(image, cmap=plt.get_cmap('gray'))
 plt.title(f"Digit: {digit}")
 plt.xticks([])
 plt.yticks([])
plt.figure(figsize=(16, 10))
for i in range(20):
 plot_digit(X_train[i], y_train[i], plt, i) 
plt.show()

# %%
X_train = X_train.reshape((X_train.shape + (1,)))
X_test = X_test.reshape((X_test.shape + (1,)))
y_train[0:20]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4, 3, 5, 3, 6, 1, 7, 2, 8, 6, 9],
#       dtype=uint8)

# %%
# creating the model

model = Sequential([
 Conv2D(32, (3, 3), activation="relu", input_shape=(28, 28, 1)),
 MaxPooling2D((2, 2)),
 Flatten(),
 Dense(100, activation="relu"),
 Dense(10, activation="softmax")
])

# %%
optimizer = SGD(learning_rate=0.01, momentum=0.9)
model.compile(
 optimizer=optimizer, 
 loss="sparse_categorical_crossentropy", 
 metrics=["accuracy"]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  flatten (Flatten)           (None, 5408)              0
#
#  dense (Dense)               (None, 100)               540900
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 542,230
# Trainable params: 542,230
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model
history = model.fit(X_train, y_train,validation_data = (x_test,y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 62s 31ms/step - loss: 0.2315 - accuracy: 0.9303 - val_loss: 16.4396 - val_accuracy: 0.9680
# Epoch 2/10
# 1875/1875 [==============================] - 44s 24ms/step - loss: 0.0742 - accuracy: 0.9777 - val_loss: 11.1723 - val_accuracy: 0.9779
# Epoch 3/10
# 1875/1875 [==============================] - 75s 40ms/step - loss: 0.0488 - accuracy: 0.9850 - val_loss: 11.7264 - val_accuracy: 0.9784
# Epoch 4/10
# 1875/1875 [==============================] - 66s 35ms/step - loss: 0.0340 - accuracy: 0.9898 - val_loss: 15.2963 - val_accuracy: 0.9751
# Epoch 5/10
# 1875/1875 [==============================] - 64s 34ms/step - loss: 0.0260 - accuracy: 0.9919 - val_loss: 14.4302 - val_accuracy: 0.9792
# Epoch 6/10
# 1875/1875 [==============================] - 75s 40ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 16.1553 - val_accuracy: 0.9783
# Epoch 7/10
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 19.8528 - val_accuracy: 0.9711
# Epoch 8/10
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 13.0334 - val_accuracy: 0.9844
# Epoch 9/10
# 1875/1875 [==============================] - 78s 41ms/step - loss: 0.0075 - accuracy: 0.9980 - val_loss: 19.1677 - val_accuracy: 0.9796
# Epoch 10/10
# 1875/1875 [==============================] - 61s 33ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 18.6414 - val_accuracy: 0.9799

# %%
plt.figure(figsize=(16, 10))
for i in range(20):
 image = random.choice(X_test).squeeze()
 digit = np.argmax(model.predict(image.reshape((1, 28, 28, 1)))[0], axis=-1)
 plot_digit(image, digit, plt, i)
plt.show()
# Out:
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 138ms/step

# %%
predictions = np.argmax(model.predict(X_test), axis=-1)
accuracy_score(y_test, predictions)
# Out:
# 313/313 [==============================] - 4s 13ms/step
# 0.9873

# %%
# estimating the model performance

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])    #Test Loss
print('Test accuracy:', score[1])    #Test Accuracy
# Out:
# Test loss: 0.039056017994880676
# Test accuracy: 0.9872999787330627

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = 10
epochs_range = range(epochs)

# %%
import os
# plotting the metrics
fig = plt.figure()
plt.figure(figsize=(8, 8))

plt.subplot(2,1,1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')


plt.subplot(2,1,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.tight_layout()

# %%
#Save the model
# serialize model to JSON
model_digit_json = model.to_json()
with open("model_digit.json", "w") as json_file:
 json_file.write(model_digit_json)
# serialize weights to HDF5
model.save_weights("model_digit.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
